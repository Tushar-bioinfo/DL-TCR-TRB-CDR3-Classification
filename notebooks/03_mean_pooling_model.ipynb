# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import pandas as pd
import json
from pathlib import Path
import numpy as np
import random

# %% [markdown]
# ### Constants

# %%
# Paths
basedir = Path("/Users/tusharsingh/Work/Project/DL-cdr3-tumor")
jsonl_file = basedir / "processed" / "cdr3_tumor_normal.jsonl"
# Constants
MAX_SEQ_LEN = 22
MAX_CDR3_PER_PATIENT = 20
VOCAB_SIZE = 22  # 20 AAs + PAD + UNK
EMBEDDING_DIM = 32
BATCH_SIZE = 32
EPOCHS = 100
LEARNING_RATE = 0.1

# %% [markdown]
# ### Dataset Class

# %%
class PatientCDR3Dataset(Dataset):
    def __init__(self, jsonl_path):
        self.samples = []
        with open(jsonl_path, 'r') as f:
            for line in f:
                entry = json.loads(line)
                self.samples.append(entry)

        self.label_map = {"tumor": 1, "normal": 0}

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        x = np.array(self.samples[idx]["cdr3s"], dtype=np.int64)
        y = self.label_map[self.samples[idx]["label"]]
        return torch.tensor(x), torch.tensor(y)

# %% [markdown]
# ### Mean Pooling model

# %%
class MeanPoolModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super(MeanPoolModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.fc = nn.Linear(embedding_dim, 1)
    
    def forward(self, x):
        # x shape: [batch_size, num_cdr3s, seq_len]
        bsz, n_seqs, seq_len = x.shape
        x = x.view(bsz * n_seqs, seq_len)

        # Embed
        embedded = self.embedding(x)  # [bsz * n_seqs, seq_len, embed_dim]

        # Mean pool over sequence
        mean_seq = embedded.mean(dim=1)  # [bsz * n_seqs, embed_dim]

        # Reshape back to [batch_size, n_seqs, embed_dim]
        mean_seq = mean_seq.view(bsz, n_seqs, -1)

        # Mean pool across CDR3s
        pooled = mean_seq.mean(dim=1)  # [batch_size, embed_dim]

        out = self.fc(pooled)  # [batch_size, 1]
        return torch.sigmoid(out).squeeze()

# %% [markdown]
# ### Train and Evaluate Functions

# %%
def train_epoch(model, loader, criterion, optimizer):
    model.train()
    total_loss = 0
    correct = 0
    for x, y in loader:
        optimizer.zero_grad()
        output = model(x)
        loss = criterion(output, y.float())
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        preds = (output > 0.5).int()
        correct += (preds == y).sum().item()
    
    return total_loss / len(loader), correct / len(loader.dataset)

def evaluate(model, loader):
    model.eval()
    correct = 0
    with torch.no_grad():
        for x, y in loader:
            output = model(x)
            preds = (output > 0.5).int()
            correct += (preds == y).sum().item()
    return correct / len(loader.dataset)

# %% [markdown]
# ### Training

# %%
# Load dataset
full_dataset = PatientCDR3Dataset(jsonl_file)
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_ds, val_ds = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE)

# Initialize model
model = MeanPoolModel(VOCAB_SIZE, EMBEDDING_DIM)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# Train loop
best_val_acc = 0
for epoch in range(1, EPOCHS + 1):
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer)
    val_acc = evaluate(model, val_loader)
    print(f"Epoch {epoch}: Train Loss = {train_loss:.4f}, Acc = {train_acc:.4f}")
    print(f"\tVal Acc = {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), basedir / "mean_pool_best_model.pt")
        print("Best model saved")
# Out:
# Epoch 1: Train Loss = 0.6961, Acc = 0.4918
# 	Val Acc = 0.4579
# Best model saved
# Epoch 2: Train Loss = 0.6999, Acc = 0.5106
# 	Val Acc = 0.5234
# Best model saved
# Epoch 3: Train Loss = 0.7191, Acc = 0.4753
# 	Val Acc = 0.4579
# Epoch 4: Train Loss = 0.6973, Acc = 0.4988
# 	Val Acc = 0.5327
# Best model saved
# Epoch 5: Train Loss = 0.6968, Acc = 0.5365
# 	Val Acc = 0.5421
# Best model saved
# Epoch 6: Train Loss = 0.6944, Acc = 0.5271
# 	Val Acc = 0.5327
# Epoch 7: Train Loss = 0.6855, Acc = 0.5741
# 	Val Acc = 0.5701
# Best model saved
# Epoch 8: Train Loss = 0.6813, Acc = 0.5765
# 	Val Acc = 0.5327
# Epoch 9: Train Loss = 0.6875, Acc = 0.5482
# 	Val Acc = 0.4673
# Epoch 10: Train Loss = 0.6820, Acc = 0.5812
# 	Val Acc = 0.5421
# Epoch 11: Train Loss = 0.6805, Acc = 0.5765
# 	Val Acc = 0.5234
# Epoch 12: Train Loss = 0.6881, Acc = 0.5647
# 	Val Acc = 0.5140
# Epoch 13: Train Loss = 0.6980, Acc = 0.5035
# 	Val Acc = 0.5607
# Epoch 14: Train Loss = 0.6899, Acc = 0.5600
# 	Val Acc = 0.4860
# Epoch 15: Train Loss = 0.6837, Acc = 0.5741
# 	Val Acc = 0.5234
# Epoch 16: Train Loss = 0.6683, Acc = 0.5647
# 	Val Acc = 0.5421
# Epoch 17: Train Loss = 0.6929, Acc = 0.5459
# 	Val Acc = 0.5047
# Epoch 18: Train Loss = 0.6857, Acc = 0.5529
# 	Val Acc = 0.5140
# Epoch 19: Train Loss = 0.6876, Acc = 0.5576
# 	Val Acc = 0.5421
# Epoch 20: Train Loss = 0.6852, Acc = 0.5624
# 	Val Acc = 0.5514
# Epoch 21: Train Loss = 0.6759, Acc = 0.5506
# 	Val Acc = 0.5327
# Epoch 22: Train Loss = 0.6937, Acc = 0.5459
# 	Val Acc = 0.5327
# Epoch 23: Train Loss = 0.6749, Acc = 0.5718
# 	Val Acc = 0.5701
# Epoch 24: Train Loss = 0.6798, Acc = 0.5788
# 	Val Acc = 0.5327
# Epoch 25: Train Loss = 0.6731, Acc = 0.5882
# 	Val Acc = 0.5047
# Epoch 26: Train Loss = 0.6771, Acc = 0.5906
# 	Val Acc = 0.5047
# Epoch 27: Train Loss = 0.6877, Acc = 0.5506
# 	Val Acc = 0.4673
# Epoch 28: Train Loss = 0.6910, Acc = 0.5459
# 	Val Acc = 0.5140
# Epoch 29: Train Loss = 0.6868, Acc = 0.5859
# 	Val Acc = 0.4393
# Epoch 30: Train Loss = 0.6885, Acc = 0.5765
# 	Val Acc = 0.4766
# Epoch 31: Train Loss = 0.6747, Acc = 0.6071
# 	Val Acc = 0.5701
# Epoch 32: Train Loss = 0.6810, Acc = 0.5835
# 	Val Acc = 0.4579
# Epoch 33: Train Loss = 0.6885, Acc = 0.5506
# 	Val Acc = 0.4673
# Epoch 34: Train Loss = 0.6777, Acc = 0.5788
# 	Val Acc = 0.4860
# Epoch 35: Train Loss = 0.6754, Acc = 0.5718
# 	Val Acc = 0.5514
# Epoch 36: Train Loss = 0.6758, Acc = 0.5953
# 	Val Acc = 0.5234
# Epoch 37: Train Loss = 0.6685, Acc = 0.6024
# 	Val Acc = 0.4766
# Epoch 38: Train Loss = 0.6717, Acc = 0.5929
# 	Val Acc = 0.5607
# Epoch 39: Train Loss = 0.6742, Acc = 0.5882
# 	Val Acc = 0.5234
# Epoch 40: Train Loss = 0.6809, Acc = 0.5694
# 	Val Acc = 0.5421
# Epoch 41: Train Loss = 0.6769, Acc = 0.5929
# 	Val Acc = 0.4579
# Epoch 42: Train Loss = 0.6736, Acc = 0.5718
# 	Val Acc = 0.5327
# Epoch 43: Train Loss = 0.6756, Acc = 0.5835
# 	Val Acc = 0.5514
# Epoch 44: Train Loss = 0.6833, Acc = 0.5694
# 	Val Acc = 0.5140
# Epoch 45: Train Loss = 0.6733, Acc = 0.6000
# 	Val Acc = 0.5421
# Epoch 46: Train Loss = 0.6725, Acc = 0.5906
# 	Val Acc = 0.5421
# Epoch 47: Train Loss = 0.6656, Acc = 0.5882
# 	Val Acc = 0.5607
# Epoch 48: Train Loss = 0.6755, Acc = 0.6024
# 	Val Acc = 0.5327
# Epoch 49: Train Loss = 0.6773, Acc = 0.5694
# 	Val Acc = 0.5327
# Epoch 50: Train Loss = 0.6765, Acc = 0.5553
# 	Val Acc = 0.4766
# Epoch 51: Train Loss = 0.6800, Acc = 0.5576
# 	Val Acc = 0.5514
# Epoch 52: Train Loss = 0.6763, Acc = 0.5788
# 	Val Acc = 0.5514
# Epoch 53: Train Loss = 0.6801, Acc = 0.5812
# 	Val Acc = 0.5421
# Epoch 54: Train Loss = 0.6629, Acc = 0.5765
# 	Val Acc = 0.5327
# Epoch 55: Train Loss = 0.6783, Acc = 0.6071
# 	Val Acc = 0.4766
# Epoch 56: Train Loss = 0.6810, Acc = 0.5624
# 	Val Acc = 0.4579
# Epoch 57: Train Loss = 0.6941, Acc = 0.5224
# 	Val Acc = 0.5234
# Epoch 58: Train Loss = 0.6868, Acc = 0.5647
# 	Val Acc = 0.5607
# Epoch 59: Train Loss = 0.6666, Acc = 0.5600
# 	Val Acc = 0.5607
# Epoch 60: Train Loss = 0.6695, Acc = 0.5718
# 	Val Acc = 0.5047
# Epoch 61: Train Loss = 0.6943, Acc = 0.5694
# 	Val Acc = 0.4579
# Epoch 62: Train Loss = 0.7407, Acc = 0.4729
# 	Val Acc = 0.5421
# Epoch 63: Train Loss = 0.6869, Acc = 0.5553
# 	Val Acc = 0.5327
# Epoch 64: Train Loss = 0.6686, Acc = 0.5788
# 	Val Acc = 0.5421
# Epoch 65: Train Loss = 0.6699, Acc = 0.5929
# 	Val Acc = 0.4860
# Epoch 66: Train Loss = 0.6830, Acc = 0.5718
# 	Val Acc = 0.5234
# Epoch 67: Train Loss = 0.6677, Acc = 0.5882
# 	Val Acc = 0.5421
# Epoch 68: Train Loss = 0.6829, Acc = 0.5835
# 	Val Acc = 0.4579
# Epoch 69: Train Loss = 0.6780, Acc = 0.5741
# 	Val Acc = 0.4766
# Epoch 70: Train Loss = 0.6793, Acc = 0.5647
# 	Val Acc = 0.5327
# Epoch 71: Train Loss = 0.6682, Acc = 0.5929
# 	Val Acc = 0.5234
# Epoch 72: Train Loss = 0.6725, Acc = 0.5765
# 	Val Acc = 0.4953
# Epoch 73: Train Loss = 0.6665, Acc = 0.5929
# 	Val Acc = 0.5421
# Epoch 74: Train Loss = 0.6708, Acc = 0.5906
# 	Val Acc = 0.5514
# Epoch 75: Train Loss = 0.6654, Acc = 0.6141
# 	Val Acc = 0.4953
# Epoch 76: Train Loss = 0.6607, Acc = 0.6000
# 	Val Acc = 0.5701
# Epoch 77: Train Loss = 0.6779, Acc = 0.5624
# 	Val Acc = 0.5234
# Epoch 78: Train Loss = 0.6807, Acc = 0.5624
# 	Val Acc = 0.5607
# Epoch 79: Train Loss = 0.6688, Acc = 0.5765
# 	Val Acc = 0.5327
# Epoch 80: Train Loss = 0.6640, Acc = 0.5812
# 	Val Acc = 0.5607
# Epoch 81: Train Loss = 0.6604, Acc = 0.5976
# 	Val Acc = 0.5234
# Epoch 82: Train Loss = 0.6648, Acc = 0.6094
# 	Val Acc = 0.4673
# Epoch 83: Train Loss = 0.6791, Acc = 0.5671
# 	Val Acc = 0.5234
# Epoch 84: Train Loss = 0.6722, Acc = 0.5765
# 	Val Acc = 0.4673
# Epoch 85: Train Loss = 0.6736, Acc = 0.5906
# 	Val Acc = 0.4860
# Epoch 86: Train Loss = 0.6674, Acc = 0.5835
# 	Val Acc = 0.4673
# Epoch 87: Train Loss = 0.6984, Acc = 0.5176
# 	Val Acc = 0.4673
# Epoch 88: Train Loss = 0.6890, Acc = 0.5553
# 	Val Acc = 0.4673
# Epoch 89: Train Loss = 0.6743, Acc = 0.5835
# 	Val Acc = 0.5421
# Epoch 90: Train Loss = 0.6617, Acc = 0.5624
# 	Val Acc = 0.5234
# Epoch 91: Train Loss = 0.6974, Acc = 0.5435
# 	Val Acc = 0.5327
# Epoch 92: Train Loss = 0.6800, Acc = 0.5459
# 	Val Acc = 0.5421
# Epoch 93: Train Loss = 0.6699, Acc = 0.5859
# 	Val Acc = 0.5421
# Epoch 94: Train Loss = 0.6937, Acc = 0.5718
# 	Val Acc = 0.5607
# Epoch 95: Train Loss = 0.6765, Acc = 0.5506
# 	Val Acc = 0.5514
# Epoch 96: Train Loss = 0.6883, Acc = 0.5482
# 	Val Acc = 0.5421
# Epoch 97: Train Loss = 0.6685, Acc = 0.5976
# 	Val Acc = 0.5607
# Epoch 98: Train Loss = 0.6664, Acc = 0.6141
# 	Val Acc = 0.5327
# Epoch 99: Train Loss = 0.6922, Acc = 0.5882
# 	Val Acc = 0.5327
# Epoch 100: Train Loss = 0.6833, Acc = 0.5882
# 	Val Acc = 0.5421

# %% [markdown]
# This model used tokenized and padded CDR3 sequences, followed by a simple embedding and mean pooling across the 20 normalized CDR3s per patient. Despite its simplicity, it achieved moderate performance:
#
# Final Validation Accuracy: 54.2%
#
# Best Epoch Accuracy: 58.8% (Train), 54.2% (Validation)
