# %% [markdown]
# ### Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import pandas as pd
import json
from pathlib import Path
import numpy as np
import random

# %% [markdown]
# ### Constants

# %%
# Paths
basedir = Path("/Users/tusharsingh/Work/Project/DL-cdr3-tumor")
jsonl_file = basedir / "processed" / "cdr3_tumor_normal.jsonl"
# Constants
MAX_SEQ_LEN = 30
MAX_CDR3_PER_PATIENT = 20
VOCAB_SIZE = 22  # 20 AAs + PAD + UNK
EMBEDDING_DIM = 32
BATCH_SIZE = 32
EPOCHS = 100
LEARNING_RATE = 0.1

# %% [markdown]
# ### Dataset Class

# %%
class PatientCDR3Dataset(Dataset):
    def __init__(self, jsonl_path):
        self.samples = []
        with open(jsonl_path, 'r') as f:
            for line in f:
                entry = json.loads(line)
                self.samples.append(entry)

        self.label_map = {"tumor": 1, "normal": 0}

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        x = np.array(self.samples[idx]["cdr3s"], dtype=np.int64)
        y = self.label_map[self.samples[idx]["label"]]
        return torch.tensor(x), torch.tensor(y)

# %% [markdown]
# ### Mean Pooling model

# %%
class MeanPoolModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim):
        super(MeanPoolModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.fc = nn.Linear(embedding_dim, 1)
    
    def forward(self, x):
        # x shape: [batch_size, num_cdr3s, seq_len]
        bsz, n_seqs, seq_len = x.shape
        x = x.view(bsz * n_seqs, seq_len)

        # Embed
        embedded = self.embedding(x)  # [bsz * n_seqs, seq_len, embed_dim]

        # Mean pool over sequence
        mean_seq = embedded.mean(dim=1)  # [bsz * n_seqs, embed_dim]

        # Reshape back to [batch_size, n_seqs, embed_dim]
        mean_seq = mean_seq.view(bsz, n_seqs, -1)

        # Mean pool across CDR3s
        pooled = mean_seq.mean(dim=1)  # [batch_size, embed_dim]

        out = self.fc(pooled)  # [batch_size, 1]
        return torch.sigmoid(out).squeeze()

# %% [markdown]
# ### Train and Evaluate Functions

# %%
def train_epoch(model, loader, criterion, optimizer):
    model.train()
    total_loss = 0
    correct = 0
    for x, y in loader:
        optimizer.zero_grad()
        output = model(x)
        loss = criterion(output, y.float())
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        preds = (output > 0.5).int()
        correct += (preds == y).sum().item()
    
    return total_loss / len(loader), correct / len(loader.dataset)

def evaluate(model, loader):
    model.eval()
    correct = 0
    with torch.no_grad():
        for x, y in loader:
            output = model(x)
            preds = (output > 0.5).int()
            correct += (preds == y).sum().item()
    return correct / len(loader.dataset)

# %% [markdown]
# ### Training

# %%
# Load dataset
full_dataset = PatientCDR3Dataset(jsonl_file)
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_ds, val_ds = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE)

# Initialize model
model = MeanPoolModel(VOCAB_SIZE, EMBEDDING_DIM)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# Train loop
best_val_acc = 0
for epoch in range(1, EPOCHS + 1):
    train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer)
    val_acc = evaluate(model, val_loader)
    print(f"Epoch {epoch}: Train Loss = {train_loss:.4f}, Acc = {train_acc:.4f}")
    print(f"\tVal Acc = {val_acc:.4f}")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), basedir / "mean_pool_best_model.pt")
        print("Best model saved")
# Out:
# Epoch 1: Train Loss = 0.7048, Acc = 0.4800
# 	Val Acc = 0.4766
# Best model saved
# Epoch 2: Train Loss = 0.6963, Acc = 0.4729
# 	Val Acc = 0.4953
# Best model saved
# Epoch 3: Train Loss = 0.6939, Acc = 0.4965
# 	Val Acc = 0.4953
# Epoch 4: Train Loss = 0.6920, Acc = 0.5224
# 	Val Acc = 0.5981
# Best model saved
# Epoch 5: Train Loss = 0.7004, Acc = 0.5247
# 	Val Acc = 0.5327
# Epoch 6: Train Loss = 0.6929, Acc = 0.4965
# 	Val Acc = 0.5888
# Epoch 7: Train Loss = 0.6874, Acc = 0.5600
# 	Val Acc = 0.5794
# Epoch 8: Train Loss = 0.6926, Acc = 0.5106
# 	Val Acc = 0.5981
# Epoch 9: Train Loss = 0.6904, Acc = 0.5341
# 	Val Acc = 0.5140
# Epoch 10: Train Loss = 0.6814, Acc = 0.5741
# 	Val Acc = 0.5794
# Epoch 11: Train Loss = 0.7022, Acc = 0.5200
# 	Val Acc = 0.5421
# Epoch 12: Train Loss = 0.6838, Acc = 0.5647
# 	Val Acc = 0.4766
# Epoch 13: Train Loss = 0.6920, Acc = 0.5271
# 	Val Acc = 0.6542
# Best model saved
# Epoch 14: Train Loss = 0.6756, Acc = 0.5835
# 	Val Acc = 0.6168
# Epoch 15: Train Loss = 0.6821, Acc = 0.5600
# 	Val Acc = 0.5888
# Epoch 16: Train Loss = 0.6832, Acc = 0.5482
# 	Val Acc = 0.6075
# Epoch 17: Train Loss = 0.7089, Acc = 0.4965
# 	Val Acc = 0.5421
# Epoch 18: Train Loss = 0.7000, Acc = 0.5106
# 	Val Acc = 0.5514
# Epoch 19: Train Loss = 0.6747, Acc = 0.6000
# 	Val Acc = 0.6075
# Epoch 20: Train Loss = 0.6884, Acc = 0.5576
# 	Val Acc = 0.5701
# Epoch 21: Train Loss = 0.6809, Acc = 0.5553
# 	Val Acc = 0.5888
# Epoch 22: Train Loss = 0.6712, Acc = 0.5906
# 	Val Acc = 0.5607
# Epoch 23: Train Loss = 0.6744, Acc = 0.5788
# 	Val Acc = 0.5607
# Epoch 24: Train Loss = 0.6789, Acc = 0.5765
# 	Val Acc = 0.5607
# Epoch 25: Train Loss = 0.6790, Acc = 0.5506
# 	Val Acc = 0.5514
# Epoch 26: Train Loss = 0.6795, Acc = 0.5788
# 	Val Acc = 0.5794
# Epoch 27: Train Loss = 0.6812, Acc = 0.5882
# 	Val Acc = 0.4766
# Epoch 28: Train Loss = 0.6867, Acc = 0.5365
# 	Val Acc = 0.5794
# Epoch 29: Train Loss = 0.6774, Acc = 0.5435
# 	Val Acc = 0.5607
# Epoch 30: Train Loss = 0.6771, Acc = 0.5788
# 	Val Acc = 0.5701
# Epoch 31: Train Loss = 0.6659, Acc = 0.6000
# 	Val Acc = 0.5514
# Epoch 32: Train Loss = 0.6821, Acc = 0.5812
# 	Val Acc = 0.5701
# Epoch 33: Train Loss = 0.6739, Acc = 0.5741
# 	Val Acc = 0.5514
# Epoch 34: Train Loss = 0.6700, Acc = 0.5718
# 	Val Acc = 0.5327
# Epoch 35: Train Loss = 0.6794, Acc = 0.5624
# 	Val Acc = 0.5514
# Epoch 36: Train Loss = 0.6701, Acc = 0.5718
# 	Val Acc = 0.6075
# Epoch 37: Train Loss = 0.6735, Acc = 0.5906
# 	Val Acc = 0.5981
# Epoch 38: Train Loss = 0.6810, Acc = 0.5600
# 	Val Acc = 0.6075
# Epoch 39: Train Loss = 0.6891, Acc = 0.5294
# 	Val Acc = 0.5701
# Epoch 40: Train Loss = 0.6702, Acc = 0.5741
# 	Val Acc = 0.5234
# Epoch 41: Train Loss = 0.6785, Acc = 0.5765
# 	Val Acc = 0.5701
# Epoch 42: Train Loss = 0.6693, Acc = 0.5929
# 	Val Acc = 0.5794
# Epoch 43: Train Loss = 0.6663, Acc = 0.5671
# 	Val Acc = 0.6075
# Epoch 44: Train Loss = 0.6841, Acc = 0.5671
# 	Val Acc = 0.5421
# Epoch 45: Train Loss = 0.6786, Acc = 0.5671
# 	Val Acc = 0.5981
# Epoch 46: Train Loss = 0.6724, Acc = 0.5694
# 	Val Acc = 0.5888
# Epoch 47: Train Loss = 0.6676, Acc = 0.5835
# 	Val Acc = 0.5794
# Epoch 48: Train Loss = 0.6768, Acc = 0.5576
# 	Val Acc = 0.5327
# Epoch 49: Train Loss = 0.6748, Acc = 0.5953
# 	Val Acc = 0.5794
# Epoch 50: Train Loss = 0.6706, Acc = 0.5529
# 	Val Acc = 0.5514
# Epoch 51: Train Loss = 0.6879, Acc = 0.5624
# 	Val Acc = 0.6075
# Epoch 52: Train Loss = 0.6937, Acc = 0.5741
# 	Val Acc = 0.5888
# Epoch 53: Train Loss = 0.6779, Acc = 0.5882
# 	Val Acc = 0.5607
# Epoch 54: Train Loss = 0.6826, Acc = 0.5835
# 	Val Acc = 0.5794
# Epoch 55: Train Loss = 0.6814, Acc = 0.5435
# 	Val Acc = 0.5421
# Epoch 56: Train Loss = 0.6802, Acc = 0.5671
# 	Val Acc = 0.5327
# Epoch 57: Train Loss = 0.6879, Acc = 0.5412
# 	Val Acc = 0.5888
# Epoch 58: Train Loss = 0.6934, Acc = 0.5341
# 	Val Acc = 0.5794
# Epoch 59: Train Loss = 0.6732, Acc = 0.5553
# 	Val Acc = 0.5327
# Epoch 60: Train Loss = 0.6639, Acc = 0.6000
# 	Val Acc = 0.5981
# Epoch 61: Train Loss = 0.6737, Acc = 0.5459
# 	Val Acc = 0.5514
# Epoch 62: Train Loss = 0.6631, Acc = 0.5953
# 	Val Acc = 0.5421
# Epoch 63: Train Loss = 0.6540, Acc = 0.5906
# 	Val Acc = 0.5701
# Epoch 64: Train Loss = 0.6722, Acc = 0.5647
# 	Val Acc = 0.5794
# Epoch 65: Train Loss = 0.6932, Acc = 0.5200
# 	Val Acc = 0.5047
# Epoch 66: Train Loss = 0.6763, Acc = 0.5600
# 	Val Acc = 0.6075
# Epoch 67: Train Loss = 0.6708, Acc = 0.5953
# 	Val Acc = 0.5234
# Epoch 68: Train Loss = 0.6842, Acc = 0.6000
# 	Val Acc = 0.5701
# Epoch 69: Train Loss = 0.7164, Acc = 0.5200
# 	Val Acc = 0.5607
# Epoch 70: Train Loss = 0.7061, Acc = 0.5435
# 	Val Acc = 0.5981
# Epoch 71: Train Loss = 0.6938, Acc = 0.5529
# 	Val Acc = 0.5888
# Epoch 72: Train Loss = 0.6916, Acc = 0.5482
# 	Val Acc = 0.5421
# Epoch 73: Train Loss = 0.6958, Acc = 0.5388
# 	Val Acc = 0.5888
# Epoch 74: Train Loss = 0.6867, Acc = 0.5553
# 	Val Acc = 0.5607
# Epoch 75: Train Loss = 0.6669, Acc = 0.5812
# 	Val Acc = 0.5421
# Epoch 76: Train Loss = 0.6745, Acc = 0.5718
# 	Val Acc = 0.5794
# Epoch 77: Train Loss = 0.6732, Acc = 0.6047
# 	Val Acc = 0.5327
# Epoch 78: Train Loss = 0.6792, Acc = 0.5529
# 	Val Acc = 0.5514
# Epoch 79: Train Loss = 0.6599, Acc = 0.5647
# 	Val Acc = 0.5888
# Epoch 80: Train Loss = 0.6698, Acc = 0.5718
# 	Val Acc = 0.5421
# Epoch 81: Train Loss = 0.6638, Acc = 0.5859
# 	Val Acc = 0.6168
# Epoch 82: Train Loss = 0.7092, Acc = 0.5271
# 	Val Acc = 0.5701
# Epoch 83: Train Loss = 0.6844, Acc = 0.5224
# 	Val Acc = 0.5514
# Epoch 84: Train Loss = 0.6721, Acc = 0.5765
# 	Val Acc = 0.5794
# Epoch 85: Train Loss = 0.6632, Acc = 0.5647
# 	Val Acc = 0.5888
# Epoch 86: Train Loss = 0.6563, Acc = 0.5788
# 	Val Acc = 0.5888
# Epoch 87: Train Loss = 0.6731, Acc = 0.6000
# 	Val Acc = 0.5794
# Epoch 88: Train Loss = 0.6686, Acc = 0.6071
# 	Val Acc = 0.5514
# Epoch 89: Train Loss = 0.6717, Acc = 0.5788
# 	Val Acc = 0.5981
# Epoch 90: Train Loss = 0.6734, Acc = 0.5600
# 	Val Acc = 0.5234
# Epoch 91: Train Loss = 0.6636, Acc = 0.5788
# 	Val Acc = 0.5421
# Epoch 92: Train Loss = 0.6736, Acc = 0.5718
# 	Val Acc = 0.5607
# Epoch 93: Train Loss = 0.6655, Acc = 0.5788
# 	Val Acc = 0.5421
# Epoch 94: Train Loss = 0.6717, Acc = 0.5576
# 	Val Acc = 0.6075
# Epoch 95: Train Loss = 0.6675, Acc = 0.5765
# 	Val Acc = 0.5234
# Epoch 96: Train Loss = 0.6696, Acc = 0.5788
# 	Val Acc = 0.5607
# Epoch 97: Train Loss = 0.6793, Acc = 0.5765
# 	Val Acc = 0.5514
# Epoch 98: Train Loss = 0.6749, Acc = 0.5765
# 	Val Acc = 0.5981
# Epoch 99: Train Loss = 0.6652, Acc = 0.5553
# 	Val Acc = 0.5421
# Epoch 100: Train Loss = 0.6624, Acc = 0.5976
# 	Val Acc = 0.5421
